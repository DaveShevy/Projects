# %%
import requests
import json

# %%
# API Key for Alpha Vantage
API = 'AAE0QVGYXSIHE0QO'

# %% [markdown]
# Alpha Intelligence

# %%
# News & Sentiments
news_and_sentiments = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=FSM&apikey={API}'
get_news_and_sentiments = requests.get(news_and_sentiments)

news_and_sentiments_json = json.dumps(get_news_and_sentiments.json(), indent=4)
print(news_and_sentiments_json)
# Out:
# {
#     "items": "50",
#     "sentiment_score_definition": "x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish",
#     "relevance_score_definition": "0 < x <= 1, with a higher score indicating higher relevance.",
#     "feed": [
#         {
#             "title": "Company Updates Reveal Strong Buys",
#             "url": "https://www.investorideas.com/news/2023/mining/08176Orogen-Royalties.asp",
#             "time_published": "20230817T162430",
#             "authors": [],
#             "summary": "August 17, 2023 ( Investorideas.com Newswire ) Global Analyst Adrian Day shares updates from several companies this week, both quarterly results and other news. In addition, recent technical difficulties delayed the writing and made this briefer than otherwise.",
#             "banner_image": "https://www.streetwisereports.com/images/61711900662dc65fc3f2e086_orogen-ermitano-img.640x0-is.jpeg",
# ...

# %% [markdown]
# Core Stock Information

# %%
# Intraday
# Need to filter to be todays date
intraday = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=FSM&interval=60min&extended_hours=false&apikey={API}'
get_intraday = requests.get(intraday)

get_intraday_json = json.dumps(get_intraday.json(), indent=4)
print(get_intraday_json)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Intraday (60min) open, high, low, close prices and volume",
#         "2. Symbol": "FSM",
#         "3. Last Refreshed": "2023-08-21 15:00:00",
#         "4. Interval": "60min",
#         "5. Output Size": "Compact",
#         "6. Time Zone": "US/Eastern"
#     },
#     "Time Series (60min)": {
#         "2023-08-21 15:00:00": {
#             "1. open": "2.9300",
#             "2. high": "2.9300",
#             "3. low": "2.9200",
#             "4. close": "2.9200",
#             "5. volume": "235684"
#         },
#         "2023-08-21 14:00:00": {
#             "1. open": "2.9200",
#             "2. high": "2.9400",
#             "3. low": "2.9200",
#             "4. close": "2.9300",
#             "5. volume": "228654"
#         },
#         "2023-08-21 13:00:00": {
#             "1. open": "2.8900",
#             "2. high": "2.9300",
#             "3. low": "2.8890",
#             "4. close": "2.9200",
# ...

# %% [markdown]
# Stock Overview

# %%
# Stock Overview
overview = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=FSM&apikey={API}'
get_overview = requests.get(overview)
overview_json = json.dumps(get_overview.json(), indent=4)
print(overview_json)
# Out:
# {
#     "Symbol": "FSM",
#     "AssetType": "Common Stock",
#     "Name": "Fortuna Silver Mines Inc",
#     "Description": "Fortuna Silver Mines Inc. is engaged in the exploration, extraction and processing of precious and base metal deposits in Latin America. The company is headquartered in Vancouver, Canada.",
#     "CIK": "1341335",
#     "Exchange": "NYSE",
#     "Currency": "USD",
#     "Country": "USA",
#     "Sector": "ENERGY & TRANSPORTATION",
#     "Industry": "GOLD AND SILVER ORES",
#     "Address": "200 BURRARD ST, SUITE 650, VANCOUVER, BC, CA",
#     "FiscalYearEnd": "December",
#     "LatestQuarter": "2023-06-30",
#     "MarketCapitalization": "849472000",
#     "EBITDA": "227022000",
#     "PERatio": "None",
#     "PEGRatio": "0",
#     "BookValue": "4.332",
#     "DividendPerShare": "0",
#     "DividendYield": "0",
#     "EPS": "-0.49",
#     "RevenuePerShareTTM": "2.289",
#     "ProfitMargin": "-0.214",
#     "OperatingMarginTTM": "-0.198",
# ...

# %% [markdown]
# Economic Indicators

# %%
# Real GDP
# Change date to be within past 4 years
real_GDP = 'https://www.alphavantage.co/query?function=REAL_GDP&interval=quarterly&apikey={API}'
get_real_GDP = requests.get(real_GDP)
real_GDP_json = json.dumps(get_real_GDP.json(), indent=4)
print(real_GDP_json)

# %%
# Treasury Yield
# Change this to only look at past year.
treasury_yield = 'https://www.alphavantage.co/query?function=TREASURY_YIELD&interval=daily&maturity=30year&apikey={API}'
get_treasury_yield = requests.get(treasury_yield)
treasury_yield_json = json.dumps(get_treasury_yield.json(), indent=4)
print(treasury_yield_json)

# Federal Funds (Interest) Rate
fed_rate = 'https://www.alphavantage.co/query?function=FEDERAL_FUNDS_RATE&interval=monthly&apikey={API}'
get_fed_rate = requests.get(fed_rate)
fed_rate_json = json.dumps(get_fed_rate.json(), indent=4)
print(fed_rate_json)

# %%
# CPI
cpi = 'https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey={API}'
get_cpi = requests.get(cpi)
cpi_json = json.dumps(get_cpi.json(), indent=4)
print(cpi_json)

# Retail Sales
retail_sales = 'https://www.alphavantage.co/query?function=RETAIL_SALES&apikey={API}'
get_retail_sales = requests.get(retail_sales)
retail_sales_json = json.dumps(get_retail_sales.json(), indent=4)
print(retail_sales_json)

# Durable Goods Orders
durable_good_orders = 'https://www.alphavantage.co/query?function=DURABLES&apikey={API}'
get_durable_good_orders = requests.get(durable_good_orders)
durable_good_orders_json = json.dumps(get_durable_good_orders.json(), indent=4)
print(durable_good_orders_json)

# %%
# Unemployment Rate
unemployment_rate = 'https://www.alphavantage.co/query?function=UNEMPLOYMENT&apikey={API}'
get_unemployment_rate = requests.get(unemployment_rate)
unemployment_rate_json = json.dumps(get_unemployment_rate.json(), indent=4)
print(unemployment_rate_json)

# Nonfarm Payroll 
nonfarm_payroll = 'https://www.alphavantage.co/query?function=NONFARM_PAYROLL&apikey={API}'
get_nonfarm_payroll = requests.get(nonfarm_payroll)
nonfarm_payroll_json = json.dumps(get_nonfarm_payroll.json(), indent=4)
print(nonfarm_payroll_json)

# %% [markdown]
# Technical Analysis/Indicators
# - Intraday (Day Trading) Technical Analysis for the Day
# - Swing Trading Technical Analysis 3-6 Months

# %%
## Day Trading 
# Trend Indicators
SMA = 'https://www.alphavantage.co/query?function=SMA&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={API}'# Simple Moving Average
EMA = 'https://www.alphavantage.co/query?function=EMA&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={API}'# Exponential Moving Average

# Momentum Indicators
PPO = 'https://www.alphavantage.co/query?function=PPO&symbol=IBM&interval=daily&series_type=close&fastperiod=10&matype=1&apikey={API}' # Percentage Price Oscillator
RSI =  'https://www.alphavantage.co/query?function=RSI&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={API}'# Relative Strength Index

# Volatility Indicators
BBANDS = 'https://www.alphavantage.co/query?function=BBANDS&symbol=IBM&interval=weekly&time_period=5&series_type=close&nbdevup=3&nbdevdn=3&apikey={API}'# Bollinger Bands
ATR =  'https://www.alphavantage.co/query?function=ATR&symbol=IBM&interval=daily&time_period=14&apikey={API}'# Average True Range

# Volume Indicators
OBV = 'https://www.alphavantage.co/query?function=OBV&symbol=IBM&interval=weekly&apikey={API}'# On Balance Volume

# Oscillators
STOCH = 'https://www.alphavantage.co/query?function=STOCH&symbol=IBM&interval=daily&apikey={API}'# Stochastic Oscillator
ADX = 'https://www.alphavantage.co/query?function=ADX&symbol=IBM&interval=daily&time_period=10&apikey={API}'# Average Directional Movement Index


get_SMA = requests.get(SMA)
SMA_json = json.dumps(get_SMA.json(), indent=4)
print(SMA_json)

# %%
## Swing Trading
# Trend Indicators
SMA = 'https://www.alphavantage.co/query?function=SMA&symbol=IBM&interval=1min&time_period=10&series_type=open&apikey={API}'# Simple Moving Average
EMA = 'https://www.alphavantage.co/query?function=EMA&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={API}'# Exponential Moving Average

# Momentum Indicators
PPO = 'https://www.alphavantage.co/query?function=PPO&symbol=IBM&interval=daily&series_type=close&fastperiod=10&matype=1&apikey={API}' # Percentage Price Oscillator
RSI =  'https://www.alphavantage.co/query?function=RSI&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={API}'# Relative Strength Index

# Volatility Indicators
BBANDS = 'https://www.alphavantage.co/query?function=BBANDS&symbol=IBM&interval=weekly&time_period=5&series_type=close&nbdevup=3&nbdevdn=3&apikey={API}'# Bollinger Bands
ATR =  'https://www.alphavantage.co/query?function=ATR&symbol=IBM&interval=daily&time_period=14&apikey={API}'# Average True Range

# Volume Indicators
OBV = 'https://www.alphavantage.co/query?function=OBV&symbol=IBM&interval=weekly&apikey={API}'# On Balance Volume

# Oscillators
STOCH = 'https://www.alphavantage.co/query?function=STOCH&symbol=IBM&interval=daily&apikey={API}'# Stochastic Oscillator
ADX = 'https://www.alphavantage.co/query?function=ADX&symbol=IBM&interval=daily&time_period=10&apikey={API}'# Average Directional Movement Index
